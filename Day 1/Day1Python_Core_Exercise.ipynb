# %% [markdown]
# <a href="https://colab.research.google.com/github/dipanwitad-create/NASSCOM_FDP_programme/blob/main/Day1Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------

# %%
raw_sensor_data = []

base_time = datetime.datetime.now()

for i in range(100):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    timestamp = (base_time + datetime.timedelta(minutes=i)).strftime('%Y-%m-%d %H:%M:%S')

    device_id = f"DEV{i+1:03d}"

    raw_sensor_data.append(
        (timestamp, device_id, device_type, location, value)
    )

# %%
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': reading[0],
            'device_id': reading[1],
            'location': reading[3],
            'temperature_celsius': reading[4]
        })

# %%
unique_locations = {reading[3] for reading in raw_sensor_data}

# %%
device_stats = {
    device: [float('inf'), float('-inf')]
    for device in DEVICE_TYPES
}

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    device_stats[device_type][0] = min(device_stats[device_type][0], value)
    device_stats[device_type][1] = max(device_stats[device_type][1], value)

device_stats = {
    k: tuple(v)
    for k, v in device_stats.items()
}

# %%
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

# %%
sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]
substring_2 = sample_string[:6][::-1]

print(substring_1)
print(substring_2)
# Out:
# Programming
# nohtyP

# %%
fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

# %%
def get_readings_by_location(readings_list, target_location):
    return [
        reading
        for reading in readings_list
        if reading[3] == target_location
    ]

# %%
def calculate_average_temperature(temp_data_list):
    if not temp_data_list:
        return 0.0

    total = sum(
        item['temperature_celsius']
        for item in temp_data_list
    )

    return total / len(temp_data_list)

# %%
def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )

# %%
random_values = [
    random.randint(100, 200)
    for _ in range(5)
]

print(random_values)
# Out:
# [181, 179, 142, 139, 144]

# %%
import os

# Create folder if not exists
reports_dir = 'sensor_reports'
os.makedirs(reports_dir, exist_ok=True)

report_filename = os.path.join(reports_dir, 'temperature_report.txt')

# Sample data (replace with your own if available)
temperature_readings = [
    {
        'timestamp': '2025-01-01 10:00:00',
        'device_id': 'DEV001',
        'location': 'Lab1',
        'temperature_celsius': 25.6
    },
    {
        'timestamp': '2025-01-01 10:05:00',
        'device_id': 'DEV002',
        'location': 'Lab2',
        'temperature_celsius': 27.3
    },
    {
        'timestamp': '2025-01-01 10:10:00',
        'device_id': 'DEV003',
        'location': 'OfficeA',
        'temperature_celsius': 24.8
    }
]

# %%
import os

# Create folder
reports_dir = 'sensor_reports'
os.makedirs(reports_dir, exist_ok=True)

# File path
report_filename = os.path.join(reports_dir, 'temperature_report.txt')

# Sample report data
lines = [
    "[2025-01-01 10:00:00] Device DEV001 at Lab1: 25.6°C\n",
    "[2025-01-01 10:05:00] Device DEV002 at Lab2: 27.3°C\n",
    "[2025-01-01 10:10:00] Device DEV003 at OfficeA: 24.8°C\n"
]

# Write file
with open(report_filename, 'w') as f:
    f.writelines(lines)

print("File created successfully!")
# Out:
# File created successfully!

# %%
print(os.path.exists(report_filename))
# Out:
# True

# %%
# 4.2 Read the content of temperature_report.txt

read_report_lines = []

try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()

    print("\nFirst 3 lines of the report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print("Error reading file:", e)
# Out:
# First 3 lines of the report:
# [2025-01-01 10:00:00] Device DEV001 at Lab1: 25.6°C
# [2025-01-01 10:05:00] Device DEV002 at Lab2: 27.3°C
# [2025-01-01 10:10:00] Device DEV003 at OfficeA: 24.8°C
