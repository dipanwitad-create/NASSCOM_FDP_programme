# %% [markdown]
# <a href="https://colab.research.google.com/github/dipanwitad-create/NASSCOM_FDP_programme/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------

# %%
# --- Global Data for the Exercise (Simulated Data) ---
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

# %%
# --- Task 1 ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate raw_sensor_data
raw_sensor_data = []

base_time = datetime.datetime.now()

for i in range(100):
    timestamp = (base_time + datetime.timedelta(minutes=i)).strftime(
        '%Y-%m-%d %H:%M:%S'
    )

    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    raw_sensor_data.append(
        (timestamp, device_id, device_type, location, value)
    )

print(f"Generated {len(raw_sensor_data)} sensor readings.")

# 1.2 Temperature readings list of dictionaries
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': reading[0],
            'device_id': reading[1],
            'location': reading[3],
            'temperature_celsius': reading[4]
        })

print(f"Temperature readings: {len(temperature_readings)}")

# 1.3 Unique locations set
unique_locations = {reading[3] for reading in raw_sensor_data}

print("Unique locations:", unique_locations)

# 1.4 Device statistics
device_stats = {}

for device_type in DEVICE_TYPES:
    device_stats[device_type] = (float('inf'), float('-inf'))

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    device_stats[device_type] = (
        min(current_min, value),
        max(current_max, value)
    )

print("Device stats:")
for k, v in device_stats.items():
    print(k, v)

# 1.5 Advanced Slicing
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

sample_string = "PythonProgrammingIsFun"

# 1.5.1
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

# 1.5.2
substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]

print("Substring 1:", substring_1)
print("Substring 2:", substring_2)

# 1.5.3
fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print("5th reading device type:", fifth_reading_device_type)
print("Suffix:", device_type_suffix)
# Out:
# --- Task 1: Data Generation and Basic Structures ---
# Generated 100 sensor readings.
# Temperature readings: 18
# Unique locations: {'OfficeA', 'OfficeB', 'Lab1', 'Lab2', 'Warehouse'}
# Device stats:
# Temperature_Sensor (19.4, 29.88)
# Humidity_Sensor (30.06, 79.08)
# Pressure_Sensor (982.79, 1029.11)
# Light_Sensor (130.74, 989.17)
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# Substring 1: Programming
# Substring 2: nohtyP
# 5th reading device type: Temperature_Sensor
# Suffix: Sensor

# %%
# --- Task 2 ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1
def get_readings_by_location(readings_list, target_location):
    return [
        reading for reading in readings_list
        if reading[3] == target_location
    ]


# 2.2
def calculate_average_temperature(temp_data_list):
    if not temp_data_list:
        return 0.0

    total = sum(
        reading['temperature_celsius']
        for reading in temp_data_list
    )

    return total / len(temp_data_list)


# 2.3
def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )


avg_temp = calculate_average_temperature(temperature_readings)
print(f"Average temperature: {avg_temp:.2f}°C")
# Out:
# --- Task 2: Function Definitions and Usage ---
# Average temperature: 25.19°C

# %%
raw_sensor_data
# Out:
# [('2026-06-10 09:01:50', 'DEV001', 'Light_Sensor', 'OfficeA', 640.87),
#  ('2026-06-10 09:02:50', 'DEV002', 'Pressure_Sensor', 'OfficeA', 999.5),
#  ('2026-06-10 09:03:50', 'DEV003', 'Pressure_Sensor', 'OfficeA', 1013.37),
#  ('2026-06-10 09:04:50', 'DEV004', 'Humidity_Sensor', 'Lab1', 30.06),
#  ('2026-06-10 09:05:50', 'DEV005', 'Temperature_Sensor', 'Lab2', 25.61),
#  ('2026-06-10 09:06:50', 'DEV006', 'Light_Sensor', 'Warehouse', 898.93),
#  ('2026-06-10 09:07:50', 'DEV007', 'Humidity_Sensor', 'Lab2', 64.17),
#  ('2026-06-10 09:08:50', 'DEV008', 'Temperature_Sensor', 'OfficeA', 24.91),
#  ('2026-06-10 10:36:50', 'DEV096', 'Light_Sensor', 'Lab1', 350.48),
#  ('2026-06-10 10:37:50', 'DEV097', 'Humidity_Sensor', 'OfficeA', 41.41),
#  ('2026-06-10 10:38:50', 'DEV098', 'Light_Sensor', 'OfficeB', 228.39),
#  ('2026-06-10 10:39:50', 'DEV099', 'Pressure_Sensor', 'Lab1', 986.51),
#  ('2026-06-10 10:40:50', 'DEV100', 'Temperature_Sensor', 'Lab1', 20.6)]

# %%
print(len(raw_sensor_data))
# Out:
# 100

# %%
raw_sensor_data = []

base_time = datetime.datetime.now()

for i in range(100):
    timestamp = (
        base_time + datetime.timedelta(minutes=i)
    ).strftime('%Y-%m-%d %H:%M:%S')

    raw_sensor_data.append(
        (
            timestamp,
            f"DEV{i+1:03d}",
            random.choice(DEVICE_TYPES),
            random.choice(LOCATIONS),
            round(random.uniform(1, 100), 2)
        )
    )

print(len(raw_sensor_data))
# Out:
# 100

# %%
def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )

# %%
import os
print(len(temperature_readings))
print(generate_report_line)
print(os.path.exists("sensor_reports"))
# Out:
# 18
# <function generate_report_line at 0x7cb02b3837e0>
# False

# %%
read_report_lines = []

try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()

    print("\nFirst 3 lines of report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"\nError reading file '{report_filename}': {e}")
# Out:
# Error reading file 'sensor_reports/temperature_report.txt': [Errno 2] No such file or directory: 'sensor_reports/temperature_report.txt'

# %%
import os

print("Current directory:", os.getcwd())
print("sensor_reports exists:", os.path.exists("sensor_reports"))
# Out:
# Current directory: /content
# sensor_reports exists: False

# %%
print("temperature_readings exists:", "temperature_readings" in globals())

if "temperature_readings" in globals():
    print("Number of temperature readings:", len(temperature_readings))
# Out:
# temperature_readings exists: True
# Number of temperature readings: 18

# %%
os.makedirs("sensor_reports", exist_ok=True)

with open("sensor_reports/temperature_report.txt", "w") as f:
    f.write("Test line\n")

print("File exists:", os.path.exists("sensor_reports/temperature_report.txt"))
# Out:
# File exists: True

# %%
report_filename = "sensor_reports/temperature_report.txt"

os.makedirs("sensor_reports", exist_ok=True)

with open(report_filename, "w") as f:
    for reading in temperature_readings:
        f.write(generate_report_line(reading) + "\n")

print("Report created successfully.")
print("File exists:", os.path.exists(report_filename))
# Out:
# Report created successfully.
# File exists: True

# %%
with open(report_filename, "r") as f:
    read_report_lines = f.readlines()

print("First 3 lines:")

for line in read_report_lines[:3]:
    print(line.strip())
# Out:
# First 3 lines:
# [2026-06-10 09:05:50] Device DEV005 at Lab2: 25.61°C
# [2026-06-10 09:08:50] Device DEV008 at OfficeA: 24.91°C
# [2026-06-10 09:09:50] Device DEV009 at OfficeA: 26.44°C

# %%
import datetime
import random
import os

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

# --- Task 1 ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate raw_sensor_data
raw_sensor_data = []

base_time = datetime.datetime.now()

for i in range(100):
    timestamp = (base_time + datetime.timedelta(minutes=i)).strftime(
        '%Y-%m-%d %H:%M:%S'
    )

    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    raw_sensor_data.append(
        (timestamp, device_id, device_type, location, value)
    )

print(f"Generated {len(raw_sensor_data)} sensor readings.")

# 1.2 Temperature readings list of dictionaries
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': reading[0],
            'device_id': reading[1],
            'location': reading[3],
            'temperature_celsius': reading[4]
        })

print(f"Temperature readings: {len(temperature_readings)}")

# 1.3 Unique locations set
unique_locations = {reading[3] for reading in raw_sensor_data}

print("Unique locations:", unique_locations)

# 1.4 Device statistics
device_stats = {}

for device_type in DEVICE_TYPES:
    device_stats[device_type] = (float('inf'), float('-inf'))

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    device_stats[device_type] = (
        min(current_min, value),
        max(current_max, value)
    )

print("Device stats:")
for k, v in device_stats.items():
    print(k, v)

# 1.5 Advanced Slicing
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

sample_string = "PythonProgrammingIsFun"

# 1.5.1
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

# 1.5.2
substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]

print("Substring 1:", substring_1)
print("Substring 2:", substring_2)

# 1.5.3
fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print("5th reading device type:", fifth_reading_device_type)
print("Suffix:", device_type_suffix)

# --- Task 2 ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1
def get_readings_by_location(readings_list, target_location):
    return [
        reading for reading in readings_list
        if reading[3] == target_location
    ]


# 2.2
def calculate_average_temperature(temp_data_list):
    if not temp_data_list:
        return 0.0

    total = sum(
        reading['temperature_celsius']
        for reading in temp_data_list
    )

    return total / len(temp_data_list)


# 2.3
def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )


avg_temp = calculate_average_temperature(temperature_readings)
print(f"Average temperature: {avg_temp:.2f}°C")

print(len(raw_sensor_data))

# Re-generating raw_sensor_data for demonstration (original was overwritten)
raw_sensor_data = []
base_time = datetime.datetime.now()
for i in range(100):
    timestamp = (
        base_time + datetime.timedelta(minutes=i)
    ).strftime('%Y-%m-%d %H:%M:%S')
    raw_sensor_data.append(
        (
            timestamp,
            f"DEV{i+1:03d}",
            random.choice(DEVICE_TYPES),
            random.choice(LOCATIONS),
            round(random.uniform(1, 100), 2)
        )
    )
print(len(raw_sensor_data))

print(len(temperature_readings))
print(generate_report_line)

report_filename = "sensor_reports/temperature_report.txt"

os.makedirs("sensor_reports", exist_ok=True)

with open(report_filename, "w") as f:
    for reading in temperature_readings:
        f.write(generate_report_line(reading) + "\n")

print("Report created successfully.")
print("File exists:", os.path.exists(report_filename))

with open(report_filename, "r") as f:
    read_report_lines = f.readlines()

print("First 3 lines:")
for line in read_report_lines[:3]:
    print(line.strip())
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# Generated 100 sensor readings.
# Temperature readings: 28
# Unique locations: {'OfficeA', 'OfficeB', 'Lab1', 'Lab2', 'Warehouse'}
# Device stats:
# Temperature_Sensor (18.37, 29.83)
# Humidity_Sensor (30.04, 78.24)
# Pressure_Sensor (980.92, 1024.86)
# Light_Sensor (105.85, 871.98)
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# Substring 1: Programming
# Substring 2: nohtyP
# 5th reading device type: Humidity_Sensor
# Suffix: Sensor
#
# --- Task 2: Function Definitions and Usage ---
# Average temperature: 24.85°C
# 100
# 100
# 28
# <function generate_report_line at 0x7cb02aa62020>
# Report created successfully.
# File exists: True
# First 3 lines:
# [2026-06-10 09:41:10] Device DEV003 at Lab2: 27.77°C
# [2026-06-10 09:44:10] Device DEV006 at OfficeA: 22.22°C
# [2026-06-10 09:45:10] Device DEV007 at Lab1: 26.51°C
